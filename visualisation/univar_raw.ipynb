# %% [markdown]
# # Univariate plots, raw data

# %%
import pandas as pd

iris = pd.read_csv("../data/iris_cleaned.csv")

# %%
from visualisation import hist_plot

for var in iris.columns[:-1]:
    hist_plot(iris, var)
